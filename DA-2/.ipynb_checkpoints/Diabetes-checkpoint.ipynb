# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# %%
names = ['Pregnancy Count', 'Glucose', 'Blood Pressure', 'Skin Thickness', 'Insulin', 'BMI', 'Diabetes Pedigree Function', 'Age', 'Has Diabetes']
data = pd.read_csv('pima.csv',names=names)

# %%
data.head()
# Out:
#    Pregnancy Count  Glucose  Blood Pressure  Skin Thickness  Insulin   BMI  \
# 0                6      148              72              35        0  33.6
# 1                1       85              66              29        0  26.6
# 2                8      183              64               0        0  23.3
# 3                1       89              66              23       94  28.1
# 4                0      137              40              35      168  43.1
#
#    Diabetes Pedigree Function  Age  Has Diabetes
# 0                       0.627   50             1
# 1                       0.351   31             0
# 2                       0.672   32             1
# 3                       0.167   21             0
# 4                       2.288   33             1

# %%
data.shape
# Out:
# (768, 9)

# %%
data.describe()
# Out:
#        Pregnancy Count     Glucose  Blood Pressure  Skin Thickness  \
# count       768.000000  768.000000      768.000000      768.000000
# mean          3.845052  120.894531       69.105469       20.536458
# std           3.369578   31.972618       19.355807       15.952218
# min           0.000000    0.000000        0.000000        0.000000
# 25%           1.000000   99.000000       62.000000        0.000000
# 50%           3.000000  117.000000       72.000000       23.000000
# 75%           6.000000  140.250000       80.000000       32.000000
# max          17.000000  199.000000      122.000000       99.000000
#
#           Insulin         BMI  Diabetes Pedigree Function         Age  \
# count  768.000000  768.000000                  768.000000  768.000000
# mean    79.799479   31.992578                    0.471876   33.240885
# std    115.244002    7.884160                    0.331329   11.760232
# min      0.000000    0.000000                    0.078000   21.000000
# ...

# %%
data.hist(bins=50,figsize=(20,15))
plot.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_set,y_train,y_set=train_test_split(data,test_size=0.20,random_state=1)
